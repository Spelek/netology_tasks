# %% [markdown]
# ## ДЗ №1. Линейная регрессия в PyTorch

# %% [markdown]
# ### 0. Загрузка и предобработка данных

# %%
import pandas as pd

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df = pd.read_csv('housing.csv', header=None, delimiter=r"\s+", names=column_names)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
print(df.shape)
# Out:
# (506, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(df.corr().abs(),  annot=True)
# Out:
# <AxesSubplot:>

# %%
# Оставим только параметры, которые имеют высокую (> 0.4) корреляцию с целевой переменной (MEDV)
columns_best = ['LSTAT', 'INDUS', 'NOX', 'PTRATIO', 'RM', 'TAX']
# columns_best = ['LSTAT', 'RM']
X = df.loc[:, columns_best]
Y = df['MEDV']

# %%
# Отнормируем данные (?)
X = X.apply(
    lambda x: (x - x.mean()) / x.std()
)

# %%
X = X.to_numpy()
Y = Y.to_numpy()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (354, 6)
# (152, 6)
# (354,)
# (152,)

# %%
import torch

print(torch.__version__)
# Out:
# 1.11.0

# %%
# Преобразуем наши данные в тензоры PyTorch
X_train = torch.tensor(X_train, dtype=torch.float)
X_test = torch.tensor(X_test, dtype=torch.float)
Y_train = torch.tensor(Y_train, dtype=torch.float).view(-1, 1)
Y_test = torch.tensor(Y_test, dtype=torch.float).view(-1, 1)

# %% [markdown]
# ### 1. Создаем модель линейной регрессии

# %%
w_num = X_train.shape[1]
net = torch.nn.Sequential(
    torch.nn.Linear(w_num, 1)
)

torch.nn.init.normal_(net[0].weight, mean=0, std=0.1)
torch.nn.init.constant_(net[0].bias, val=0)
# Out:
# Parameter containing:
# tensor([0.], requires_grad=True)

# %%
# Задаем итератор по нашим данным
datasets = torch.utils.data.TensorDataset(X_train, Y_train)
train_iter = torch.utils.data.DataLoader(datasets, batch_size=8, shuffle=True)

# %%
loss = torch.nn.MSELoss()

# %%
optimizer = torch.optim.Adam(net.parameters(), lr=0.05)

# %%
# Запускаем обучение
num_epochs = 100
for epoch in range(1, num_epochs + 1):
    for x, y in train_iter:
        optimizer.zero_grad()
        output = net(x)
        l = loss(output, y)
        l.backward()
        optimizer.step()
    
    print("epoch {} loss: {:.4f}".format(epoch, l.item()))
    if l.item() < 1.0:
        break
# Out:
# epoch 1 loss: 43.5903
# epoch 2 loss: 25.4457
# epoch 3 loss: 14.0874
# epoch 4 loss: 3.3874
# epoch 5 loss: 19.9002
# epoch 6 loss: 11.5636
# epoch 7 loss: 3.6135
# epoch 8 loss: 7.0257
# epoch 9 loss: 3.8685
# epoch 10 loss: 187.8850
# epoch 11 loss: 76.3044
# epoch 12 loss: 21.7350
# epoch 13 loss: 4.7804
# epoch 14 loss: 4.1383
# epoch 15 loss: 4.7925
# epoch 16 loss: 12.6982
# epoch 17 loss: 14.5982
# epoch 18 loss: 29.0495
# epoch 19 loss: 4.1079
# epoch 20 loss: 10.3439
# epoch 21 loss: 258.9289
# epoch 22 loss: 6.5581
# epoch 23 loss: 41.6896
# epoch 24 loss: 25.7357
# epoch 25 loss: 19.5261
# epoch 26 loss: 3.4824
# epoch 27 loss: 7.9372
# epoch 28 loss: 5.8285
# epoch 29 loss: 10.2811
# epoch 30 loss: 72.9799
# epoch 31 loss: 99.6198
# epoch 32 loss: 99.6412
# epoch 33 loss: 63.9835
# epoch 34 loss: 8.6887
# epoch 35 loss: 31.8402
# epoch 36 loss: 202.2340
# epoch 37 loss: 5.5112
# epoch 38 loss: 3.8230
# epoch 39 loss: 28.3136
# epoch 40 loss: 3.6303
# epoch 41 loss: 3.4096
# epoch 42 loss: 1.1135
# epoch 43 loss: 237.7911
# epoch 44 loss: 40.2448
# epoch 45 loss: 9.3941
# epoch 46 loss: 38.6677
# epoch 47 loss: 4.3773
# epoch 48 loss: 1.6663
# epoch 49 loss: 18.7018
# epoch 50 loss: 14.4875
# epoch 51 loss: 59.9927
# epoch 52 loss: 3.1445
# epoch 53 loss: 52.8209
# epoch 54 loss: 0.9716

# %%
# Проверим качество модели на тестовых данных
print(loss(net(X_test), Y_test).item())
# Out:
# 26.23533821105957
